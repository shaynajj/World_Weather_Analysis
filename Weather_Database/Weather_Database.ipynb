# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Import the datetime module from the datetime library.
from datetime import datetime

# Create an endpoint URL for a city.
city_url = url + "&q=" + "Tampa"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6e3cd8c3de243459f76b8ea2354ac568
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6e3cd8c3de243459f76b8ea2354ac568&q=Tampa

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather ["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | colares
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | paita
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | coahuayana
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | tura
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | lasa
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | aksu
# Processing Record 19 of Set 1 | morondava
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | paamiut
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | komsomolskiy
# Processing Record 30 of Set 1 | verkhnetulomskiy
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | mayskiy
# Processing Record 33 of Set 1 | hashtgerd
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | bintulu
# Processing Record 37 of Set 1 | moyale
# Processing Record 38 of Set 1 | lorengau
# Processing Record 39 of Set 1 | tamiahua
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | reconquista
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | jerez
# Processing Record 45 of Set 1 | marsh harbour
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | la ronge
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | igarape-miri
# City not found. Skipping...
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | puebla
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | faya
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | araguatins
# City not found. Skipping...
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | clarksburg
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | hualmay
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | general roca
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | ostrovnoy
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | sakakah
# Processing Record 25 of Set 2 | balakhninskiy
# Processing Record 26 of Set 2 | sidi bu zayd
# City not found. Skipping...
# Processing Record 27 of Set 2 | shenjiamen
# Processing Record 28 of Set 2 | nantucket
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | hokitika
# Processing Record 31 of Set 2 | marsabit
# Processing Record 32 of Set 2 | sinnamary
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | huazolotitlan
# City not found. Skipping...
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | tautira
# Processing Record 38 of Set 2 | dese
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | north port
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | kalmunai
# Processing Record 43 of Set 2 | parauna
# Processing Record 44 of Set 2 | grafton
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | aasiaat
# Processing Record 50 of Set 2 | haines junction
# Processing Record 1 of Set 3 | vostok
# Processing Record 2 of Set 3 | aswan
# Processing Record 3 of Set 3 | la romana
# Processing Record 4 of Set 3 | hue
# Processing Record 5 of Set 3 | manihari
# Processing Record 6 of Set 3 | mutsu
# Processing Record 7 of Set 3 | beloha
# Processing Record 8 of Set 3 | pervomayskoye
# Processing Record 9 of Set 3 | kloulklubed
# Processing Record 10 of Set 3 | saint-louis
# Processing Record 11 of Set 3 | xining
# Processing Record 12 of Set 3 | foam lake
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | serenje
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | mataura
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | wucheng
# Processing Record 19 of Set 3 | tomatlan
# Processing Record 20 of Set 3 | tagusao
# Processing Record 21 of Set 3 | araguacu
# Processing Record 22 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 23 of Set 3 | raudeberg
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | hami
# Processing Record 26 of Set 3 | springbok
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | gari
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | redmond
# Processing Record 32 of Set 3 | port moresby
# Processing Record 33 of Set 3 | tabou
# Processing Record 34 of Set 3 | celestun
# Processing Record 35 of Set 3 | flin flon
# Processing Record 36 of Set 3 | olafsvik
# Processing Record 37 of Set 3 | ola
# Processing Record 38 of Set 3 | sao joao da barra
# Processing Record 39 of Set 3 | balkhash
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 3 | sorland
# Processing Record 43 of Set 3 | faanui
# Processing Record 44 of Set 3 | guerrero negro
# Processing Record 45 of Set 3 | serik
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | lagoa
# Processing Record 48 of Set 3 | grindavik
# Processing Record 49 of Set 3 | tual
# Processing Record 50 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 4 | taywarah
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | pontarlier
# Processing Record 4 of Set 4 | porosozero
# Processing Record 5 of Set 4 | ambilobe
# Processing Record 6 of Set 4 | bilibino
# Processing Record 7 of Set 4 | dunedin
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | lerwick
# Processing Record 11 of Set 4 | manta
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | azad shahr
# Processing Record 14 of Set 4 | yuganets
# Processing Record 15 of Set 4 | kichera
# Processing Record 16 of Set 4 | ardahan
# Processing Record 17 of Set 4 | barra patuca
# Processing Record 18 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 4 | hefei
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | svetlogorsk
# Processing Record 22 of Set 4 | yulara
# Processing Record 23 of Set 4 | tall kayf
# Processing Record 24 of Set 4 | savelugu
# Processing Record 25 of Set 4 | chardara
# Processing Record 26 of Set 4 | banda aceh
# Processing Record 27 of Set 4 | ketchikan
# Processing Record 28 of Set 4 | gat
# Processing Record 29 of Set 4 | launceston
# Processing Record 30 of Set 4 | kapaa
# Processing Record 31 of Set 4 | the valley
# Processing Record 32 of Set 4 | acari
# Processing Record 33 of Set 4 | cayenne
# Processing Record 34 of Set 4 | big spring
# Processing Record 35 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 4 | yellowknife
# Processing Record 37 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | dingle
# Processing Record 40 of Set 4 | velyka mykhaylivka
# Processing Record 41 of Set 4 | buta
# Processing Record 42 of Set 4 | krylovskaya
# Processing Record 43 of Set 4 | torbay
# Processing Record 44 of Set 4 | arman
# Processing Record 45 of Set 4 | fare
# Processing Record 46 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 4 | lingyuan
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | canyon
# Processing Record 50 of Set 4 | qarayeri
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | mapastepec
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | nouadhibou
# Processing Record 5 of Set 5 | imbituba
# Processing Record 6 of Set 5 | garowe
# Processing Record 7 of Set 5 | dwarka
# Processing Record 8 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 5 | nikita
# Processing Record 10 of Set 5 | krasnyy chikoy
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | isangel
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | livny
# Processing Record 15 of Set 5 | hobyo
# Processing Record 16 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 5 | ternate
# Processing Record 18 of Set 5 | chiali
# City not found. Skipping...
# Processing Record 19 of Set 5 | novobirilyussy
# Processing Record 20 of Set 5 | port hardy
# Processing Record 21 of Set 5 | little elm
# Processing Record 22 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | bangaon
# Processing Record 24 of Set 5 | santa rosa
# Processing Record 25 of Set 5 | sokoni
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | mecca
# Processing Record 28 of Set 5 | xadani
# City not found. Skipping...
# Processing Record 29 of Set 5 | banepa
# Processing Record 30 of Set 5 | sault sainte marie
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | carutapera
# Processing Record 33 of Set 5 | piopio
# Processing Record 34 of Set 5 | namioka
# Processing Record 35 of Set 5 | tiznit
# Processing Record 36 of Set 5 | tricase
# Processing Record 37 of Set 5 | itiuba
# Processing Record 38 of Set 5 | sawtell
# Processing Record 39 of Set 5 | leopold
# Processing Record 40 of Set 5 | sooke
# Processing Record 41 of Set 5 | nabire
# Processing Record 42 of Set 5 | somovo
# Processing Record 43 of Set 5 | nuuk
# Processing Record 44 of Set 5 | segovia
# Processing Record 45 of Set 5 | dubbo
# Processing Record 46 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 47 of Set 5 | constitucion
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | jiblah
# Processing Record 50 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 6 | labuhan
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | rawson
# Processing Record 4 of Set 6 | ravar
# Processing Record 5 of Set 6 | beringovskiy
# Processing Record 6 of Set 6 | camaqua
# Processing Record 7 of Set 6 | senanga
# Processing Record 8 of Set 6 | sobolevo
# Processing Record 9 of Set 6 | kenora
# Processing Record 10 of Set 6 | mount gambier
# Processing Record 11 of Set 6 | port hedland
# Processing Record 12 of Set 6 | verkhnevilyuysk
# Processing Record 13 of Set 6 | te anau
# Processing Record 14 of Set 6 | havre-saint-pierre
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | college
# Processing Record 17 of Set 6 | kotido
# Processing Record 18 of Set 6 | lohardaga
# Processing Record 19 of Set 6 | intipuca
# Processing Record 20 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 21 of Set 6 | lavrentiya
# Processing Record 22 of Set 6 | jaguey grande
# Processing Record 23 of Set 6 | khani
# Processing Record 24 of Set 6 | namatanai
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | vila velha
# Processing Record 27 of Set 6 | leh
# Processing Record 28 of Set 6 | coruripe
# Processing Record 29 of Set 6 | katsuura
# Processing Record 30 of Set 6 | poya
# Processing Record 31 of Set 6 | luchegorsk
# Processing Record 32 of Set 6 | kampot
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | san patricio
# Processing Record 35 of Set 6 | deputatskiy
# Processing Record 36 of Set 6 | baracoa
# Processing Record 37 of Set 6 | takoradi
# Processing Record 38 of Set 6 | tiksi
# Processing Record 39 of Set 6 | ullapool
# Processing Record 40 of Set 6 | kirovskiy
# Processing Record 41 of Set 6 | saldanha
# Processing Record 42 of Set 6 | muisne
# Processing Record 43 of Set 6 | hun
# Processing Record 44 of Set 6 | banjarmasin
# Processing Record 45 of Set 6 | horsham
# Processing Record 46 of Set 6 | sao filipe
# Processing Record 47 of Set 6 | sibiti
# Processing Record 48 of Set 6 | nanortalik
# Processing Record 49 of Set 6 | shingu
# Processing Record 50 of Set 6 | zhicheng
# Processing Record 1 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 7 | panaba
# Processing Record 3 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 7 | north platte
# Processing Record 7 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 7 | kijang
# Processing Record 9 of Set 7 | tartagal
# Processing Record 10 of Set 7 | zhigansk
# Processing Record 11 of Set 7 | nioro
# Processing Record 12 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 7 | xiongshi
# City not found. Skipping...
# Processing Record 14 of Set 7 | bucerias
# Processing Record 15 of Set 7 | dali
# Processing Record 16 of Set 7 | tsiroanomandidy
# Processing Record 17 of Set 7 | pevek
# Processing Record 18 of Set 7 | mahebourg
# Processing Record 19 of Set 7 | husavik
# Processing Record 20 of Set 7 | porirua
# Processing Record 21 of Set 7 | kodinsk
# Processing Record 22 of Set 7 | pangnirtung
# Processing Record 23 of Set 7 | nenjiang
# Processing Record 24 of Set 7 | erice
# Processing Record 25 of Set 7 | matamoros
# Processing Record 26 of Set 7 | emba
# Processing Record 27 of Set 7 | wagar
# Processing Record 28 of Set 7 | richards bay
# Processing Record 29 of Set 7 | bayir
# Processing Record 30 of Set 7 | parras
# City not found. Skipping...
# Processing Record 31 of Set 7 | tecpatan
# Processing Record 32 of Set 7 | tahta
# Processing Record 33 of Set 7 | igrim
# Processing Record 34 of Set 7 | san buenaventura
# Processing Record 35 of Set 7 | mandvi
# Processing Record 36 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 7 | korla
# Processing Record 38 of Set 7 | rabo de peixe
# Processing Record 39 of Set 7 | matadi
# Processing Record 40 of Set 7 | ndjole
# Processing Record 41 of Set 7 | hovd
# Processing Record 42 of Set 7 | kayes
# Processing Record 43 of Set 7 | vanino
# Processing Record 44 of Set 7 | kuah
# Processing Record 45 of Set 7 | pingzhuang
# Processing Record 46 of Set 7 | santa maria
# Processing Record 47 of Set 7 | uglegorsk
# Processing Record 48 of Set 7 | shimoda
# Processing Record 49 of Set 7 | buala
# Processing Record 50 of Set 7 | mayor pablo lagerenza
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | rapid valley
# Processing Record 3 of Set 8 | castro
# Processing Record 4 of Set 8 | roald
# Processing Record 5 of Set 8 | lanark
# Processing Record 6 of Set 8 | fortuna
# Processing Record 7 of Set 8 | naze
# Processing Record 8 of Set 8 | azul
# Processing Record 9 of Set 8 | sainte-martine
# Processing Record 10 of Set 8 | bokoro
# Processing Record 11 of Set 8 | carbonia
# Processing Record 12 of Set 8 | madisonville
# Processing Record 13 of Set 8 | honiara
# Processing Record 14 of Set 8 | sharan
# Processing Record 15 of Set 8 | karaton
# Processing Record 16 of Set 8 | adolfo lopez mateos
# Processing Record 17 of Set 8 | seydi
# Processing Record 18 of Set 8 | riyadh
# Processing Record 19 of Set 8 | krasnoselkup
# Processing Record 20 of Set 8 | truth or consequences
# Processing Record 21 of Set 8 | umm kaddadah
# Processing Record 22 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 8 | shaoyang
# Processing Record 24 of Set 8 | weyburn
# Processing Record 25 of Set 8 | miandrivazo
# Processing Record 26 of Set 8 | trstena
# Processing Record 27 of Set 8 | zyryanka
# Processing Record 28 of Set 8 | udachnyy
# Processing Record 29 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 8 | hofn
# Processing Record 31 of Set 8 | tuatapere
# Processing Record 32 of Set 8 | kattivakkam
# Processing Record 33 of Set 8 | sao miguel dos campos
# Processing Record 34 of Set 8 | mehamn
# Processing Record 35 of Set 8 | abu kamal
# Processing Record 36 of Set 8 | fairview
# Processing Record 37 of Set 8 | severo-kurilsk
# Processing Record 38 of Set 8 | grand gaube
# Processing Record 39 of Set 8 | gravdal
# Processing Record 40 of Set 8 | udgir
# Processing Record 41 of Set 8 | axim
# Processing Record 42 of Set 8 | chuy
# Processing Record 43 of Set 8 | avera
# Processing Record 44 of Set 8 | denpasar
# Processing Record 45 of Set 8 | quatre cocos
# Processing Record 46 of Set 8 | alice springs
# Processing Record 47 of Set 8 | maceio
# Processing Record 48 of Set 8 | ixtapa
# Processing Record 49 of Set 8 | benjamin constant
# Processing Record 50 of Set 8 | moerai
# Processing Record 1 of Set 9 | feijo
# Processing Record 2 of Set 9 | berbera
# Processing Record 3 of Set 9 | daru
# Processing Record 4 of Set 9 | san vicente
# Processing Record 5 of Set 9 | vestmannaeyjar
# Processing Record 6 of Set 9 | ibra
# Processing Record 7 of Set 9 | cockburn town
# Processing Record 8 of Set 9 | krasnovishersk
# Processing Record 9 of Set 9 | ewa beach
# Processing Record 10 of Set 9 | bonthe
# Processing Record 11 of Set 9 | port-gentil
# Processing Record 12 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 13 of Set 9 | loa janan
# Processing Record 14 of Set 9 | bahia de caraquez
# Processing Record 15 of Set 9 | elizabeth city
# Processing Record 16 of Set 9 | pacific grove
# Processing Record 17 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 9 | newport
# Processing Record 19 of Set 9 | sola
# Processing Record 20 of Set 9 | ulladulla
# Processing Record 21 of Set 9 | san ramon de la nueva oran
# Processing Record 22 of Set 9 | juba
# Processing Record 23 of Set 9 | singaraja
# Processing Record 24 of Set 9 | cidreira
# Processing Record 25 of Set 9 | srednekolymsk
# Processing Record 26 of Set 9 | tabas
# Processing Record 27 of Set 9 | sakaiminato
# Processing Record 28 of Set 9 | barquisimeto
# Processing Record 29 of Set 9 | jomalig
# City not found. Skipping...
# Processing Record 30 of Set 9 | sao joao do paraiso
# Processing Record 31 of Set 9 | mujiayingzi
# Processing Record 32 of Set 9 | kalabo
# Processing Record 33 of Set 9 | dourbali
# Processing Record 34 of Set 9 | essenbach
# Processing Record 35 of Set 9 | peniche
# Processing Record 36 of Set 9 | vao
# Processing Record 37 of Set 9 | bahia honda
# Processing Record 38 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 9 | rio grande
# Processing Record 40 of Set 9 | sirjan
# Processing Record 41 of Set 9 | pontes e lacerda
# Processing Record 42 of Set 9 | viedma
# Processing Record 43 of Set 9 | palmer
# Processing Record 44 of Set 9 | chino valley
# Processing Record 45 of Set 9 | egvekinot
# Processing Record 46 of Set 9 | luza
# Processing Record 47 of Set 9 | praia da vitoria
# Processing Record 48 of Set 9 | balotra
# Processing Record 49 of Set 9 | bairiki
# Processing Record 50 of Set 9 | kabalo
# Processing Record 1 of Set 10 | marsa matruh
# Processing Record 2 of Set 10 | tabuk
# Processing Record 3 of Set 10 | vila franca do campo
# Processing Record 4 of Set 10 | karagaylinskiy
# Processing Record 5 of Set 10 | havelock
# Processing Record 6 of Set 10 | broome
# Processing Record 7 of Set 10 | madimba
# Processing Record 8 of Set 10 | kaeo
# Processing Record 9 of Set 10 | dargaville
# Processing Record 10 of Set 10 | tete
# Processing Record 11 of Set 10 | jalu
# Processing Record 12 of Set 10 | trincomalee
# Processing Record 13 of Set 10 | la sarre
# Processing Record 14 of Set 10 | nchelenge
# Processing Record 15 of Set 10 | pueblo nuevo
# Processing Record 16 of Set 10 | necochea
# Processing Record 17 of Set 10 | prisacani
# Processing Record 18 of Set 10 | collie
# Processing Record 19 of Set 10 | maguilling
# Processing Record 20 of Set 10 | hirara
# Processing Record 21 of Set 10 | jieshi
# Processing Record 22 of Set 10 | saint-francois
# Processing Record 23 of Set 10 | athabasca
# Processing Record 24 of Set 10 | senador jose porfirio
# Processing Record 25 of Set 10 | orlik
# Processing Record 26 of Set 10 | essex
# Processing Record 27 of Set 10 | hambantota
# Processing Record 28 of Set 10 | wilmington
# Processing Record 29 of Set 10 | quesnel
# Processing Record 30 of Set 10 | surt
# Processing Record 31 of Set 10 | anadyr
# Processing Record 32 of Set 10 | san cristobal
# Processing Record 33 of Set 10 | doka
# Processing Record 34 of Set 10 | tazmalt
# Processing Record 35 of Set 10 | kiama
# Processing Record 36 of Set 10 | sur
# Processing Record 37 of Set 10 | san rafael
# Processing Record 38 of Set 10 | mersing
# Processing Record 39 of Set 10 | trani
# Processing Record 40 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 10 | menongue
# Processing Record 43 of Set 10 | lahaina
# Processing Record 44 of Set 10 | padang
# Processing Record 45 of Set 10 | codrington
# Processing Record 46 of Set 10 | shache
# Processing Record 47 of Set 10 | guarapari
# Processing Record 48 of Set 10 | marolambo
# Processing Record 49 of Set 10 | ahuimanu
# Processing Record 50 of Set 10 | santa fe
# Processing Record 1 of Set 11 | niksic
# Processing Record 2 of Set 11 | buenos aires
# Processing Record 3 of Set 11 | guanica
# Processing Record 4 of Set 11 | cabadiangan
# Processing Record 5 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 11 | umm lajj
# Processing Record 7 of Set 11 | itarantim
# Processing Record 8 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 11 | ridgecrest
# Processing Record 10 of Set 11 | severodvinsk
# Processing Record 11 of Set 11 | male
# Processing Record 12 of Set 11 | chopinzinho
# Processing Record 13 of Set 11 | taltal
# Processing Record 14 of Set 11 | waipawa
# Processing Record 15 of Set 11 | nador
# Processing Record 16 of Set 11 | ulaanbaatar
# Processing Record 17 of Set 11 | grand forks
# Processing Record 18 of Set 11 | baroy
# Processing Record 19 of Set 11 | flinders
# Processing Record 20 of Set 11 | providencia
# Processing Record 21 of Set 11 | keti bandar
# Processing Record 22 of Set 11 | laguna
# Processing Record 23 of Set 11 | kingman
# Processing Record 24 of Set 11 | bathurst
# Processing Record 25 of Set 11 | suifenhe
# Processing Record 26 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 11 | poum
# Processing Record 28 of Set 11 | okhotsk
# Processing Record 29 of Set 11 | kihei
# Processing Record 30 of Set 11 | sungaipenuh
# Processing Record 31 of Set 11 | araouane
# Processing Record 32 of Set 11 | obihiro
# Processing Record 33 of Set 11 | fengzhen
# Processing Record 34 of Set 11 | vuktyl
# Processing Record 35 of Set 11 | dangtu
# Processing Record 36 of Set 11 | saint-joseph
# Processing Record 37 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 11 | istok
# Processing Record 39 of Set 11 | beitbridge
# Processing Record 40 of Set 11 | fergus falls
# Processing Record 41 of Set 11 | saint-pierre
# Processing Record 42 of Set 11 | gusinoye ozero
# Processing Record 43 of Set 11 | beruwala
# Processing Record 44 of Set 11 | bathsheba
# Processing Record 45 of Set 11 | jinchang
# Processing Record 46 of Set 11 | nemuro
# Processing Record 47 of Set 11 | glencoe
# Processing Record 48 of Set 11 | boueni
# Processing Record 49 of Set 11 | porto novo
# Processing Record 50 of Set 11 | kihurio
# Processing Record 1 of Set 12 | laohekou
# Processing Record 2 of Set 12 | siavonga
# Processing Record 3 of Set 12 | linares
# Processing Record 4 of Set 12 | samarai
# Processing Record 5 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 6 of Set 12 | kisangani
# Processing Record 7 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 8 of Set 12 | ferme-neuve
# Processing Record 9 of Set 12 | placido de castro
# Processing Record 10 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 12 | somerton
# Processing Record 12 of Set 12 | west bay
# Processing Record 13 of Set 12 | la reforma
# Processing Record 14 of Set 12 | okato
# Processing Record 15 of Set 12 | siyabuswa
# Processing Record 16 of Set 12 | blagoyevo
# Processing Record 17 of Set 12 | novaya ladoga
# Processing Record 18 of Set 12 | toungoo
# City not found. Skipping...
# Processing Record 19 of Set 12 | dajal
# Processing Record 20 of Set 12 | lata
# Processing Record 21 of Set 12 | broken hill
# Processing Record 22 of Set 12 | kintampo
# Processing Record 23 of Set 12 | nhulunbuy
# Processing Record 24 of Set 12 | san andres
# Processing Record 25 of Set 12 | almenevo
# City not found. Skipping...
# Processing Record 26 of Set 12 | mutis
# Processing Record 27 of Set 12 | eregli
# Processing Record 28 of Set 12 | moose factory
# Processing Record 29 of Set 12 | sorong
# Processing Record 30 of Set 12 | azrow
# City not found. Skipping...
# Processing Record 31 of Set 12 | guisijan
# Processing Record 32 of Set 12 | yumen
# Processing Record 33 of Set 12 | akdagmadeni
# Processing Record 34 of Set 12 | rio gallegos
# Processing Record 35 of Set 12 | calama
# Processing Record 36 of Set 12 | matay
# Processing Record 37 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 12 | agadez
# Processing Record 39 of Set 12 | inuvik
# Processing Record 40 of Set 12 | ancud
# Processing Record 41 of Set 12 | bubaque
# Processing Record 42 of Set 12 | la asuncion
# Processing Record 43 of Set 12 | portland
# Processing Record 44 of Set 12 | alyangula
# Processing Record 45 of Set 12 | camana
# Processing Record 46 of Set 12 | paramonga
# Processing Record 47 of Set 12 | egyek
# Processing Record 48 of Set 12 | yerofey pavlovich
# Processing Record 49 of Set 12 | kavieng
# Processing Record 50 of Set 12 | vysokovsk
# Processing Record 1 of Set 13 | kiunga
# Processing Record 2 of Set 13 | byron bay
# Processing Record 3 of Set 13 | sosnovka
# Processing Record 4 of Set 13 | palauig
# Processing Record 5 of Set 13 | spearfish
# Processing Record 6 of Set 13 | irtyshskiy
# Processing Record 7 of Set 13 | ulety
# Processing Record 8 of Set 13 | los llanos de aridane
# Processing Record 9 of Set 13 | pijijiapan
# Processing Record 10 of Set 13 | mvangue
# Processing Record 11 of Set 13 | alofi
# Processing Record 12 of Set 13 | eureka
# Processing Record 13 of Set 13 | camacha
# Processing Record 14 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 13 | bam
# Processing Record 16 of Set 13 | tazovskiy
# Processing Record 17 of Set 13 | kieta
# Processing Record 18 of Set 13 | bandarbeyla
# Processing Record 19 of Set 13 | senhor do bonfim
# Processing Record 20 of Set 13 | beruni
# City not found. Skipping...
# Processing Record 21 of Set 13 | el dorado
# Processing Record 22 of Set 13 | mpanda
# Processing Record 23 of Set 13 | north bend
# Processing Record 24 of Set 13 | port blair
# Processing Record 25 of Set 13 | totma
# Processing Record 26 of Set 13 | najran
# Processing Record 27 of Set 13 | amambai
# Processing Record 28 of Set 13 | dauphin
# Processing Record 29 of Set 13 | antofagasta
# Processing Record 30 of Set 13 | herrin
# Processing Record 31 of Set 13 | bonito
# Processing Record 32 of Set 13 | rudnogorsk
# Processing Record 33 of Set 13 | ucluelet
# Processing Record 34 of Set 13 | marzuq
# Processing Record 35 of Set 13 | pokhara
# Processing Record 36 of Set 13 | yerbogachen
# Processing Record 37 of Set 13 | terrace
# Processing Record 38 of Set 13 | rawlins
# Processing Record 39 of Set 13 | danlugan
# Processing Record 40 of Set 13 | dakar
# Processing Record 41 of Set 13 | dudinka
# Processing Record 42 of Set 13 | jumla
# Processing Record 43 of Set 13 | buluang
# Processing Record 44 of Set 13 | goundam
# Processing Record 45 of Set 13 | tarrafal
# Processing Record 46 of Set 13 | karlskrona
# Processing Record 47 of Set 13 | coihaique
# Processing Record 48 of Set 13 | asbe teferi
# Processing Record 49 of Set 13 | vondrozo
# Processing Record 50 of Set 13 | sawakin
# Processing Record 1 of Set 14 | boynton beach
# Processing Record 2 of Set 14 | port lavaca
# Processing Record 3 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 14 | warrnambool
# Processing Record 5 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 14 | ust-barguzin
# Processing Record 7 of Set 14 | kruisfontein
# Processing Record 8 of Set 14 | wajima
# Processing Record 9 of Set 14 | mundo novo
# Processing Record 10 of Set 14 | obigarm
# Processing Record 11 of Set 14 | vallenar
# Processing Record 12 of Set 14 | bowen
# Processing Record 13 of Set 14 | voznesenskaya
# Processing Record 14 of Set 14 | adrar
# Processing Record 15 of Set 14 | luau
# Processing Record 16 of Set 14 | acapulco
# Processing Record 17 of Set 14 | karratha
# Processing Record 18 of Set 14 | clyde river
# Processing Record 19 of Set 14 | cururupu
# Processing Record 20 of Set 14 | tarves
# Processing Record 21 of Set 14 | varniai
# Processing Record 22 of Set 14 | inhambane
# Processing Record 23 of Set 14 | morant bay
# Processing Record 24 of Set 14 | bainbridge
# Processing Record 25 of Set 14 | kokopo
# Processing Record 26 of Set 14 | hastings
# Processing Record 27 of Set 14 | yasothon
# Processing Record 28 of Set 14 | bafra
# Processing Record 29 of Set 14 | pochutla
# Processing Record 30 of Set 14 | awjilah
# Processing Record 31 of Set 14 | ushtobe
# Processing Record 32 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 33 of Set 14 | puerto madryn
# Processing Record 34 of Set 14 | port shepstone
# Processing Record 35 of Set 14 | ciudad bolivar
# Processing Record 36 of Set 14 | catanzaro
# Processing Record 37 of Set 14 | kungurtug
# Processing Record 38 of Set 14 | nokaneng
# Processing Record 39 of Set 14 | noumea
# Processing Record 40 of Set 14 | los algarrobos
# Processing Record 41 of Set 14 | amazar
# Processing Record 42 of Set 14 | puteyets
# Processing Record 43 of Set 14 | troitsko-pechorsk
# Processing Record 44 of Set 14 | angoche
# Processing Record 45 of Set 14 | wundanyi
# Processing Record 46 of Set 14 | atar
# Processing Record 47 of Set 14 | sisimiut
# Processing Record 48 of Set 14 | berlevag
# Processing Record 49 of Set 14 | muros
# Processing Record 50 of Set 14 | charters towers
# Processing Record 1 of Set 15 | enzan
# Processing Record 2 of Set 15 | micheweni
# Processing Record 3 of Set 15 | puerto pinasco
# City not found. Skipping...
# Processing Record 4 of Set 15 | cap-aux-meules
# Processing Record 5 of Set 15 | hailin
# Processing Record 6 of Set 15 | teguise
# Processing Record 7 of Set 15 | deniliquin
# Processing Record 8 of Set 15 | lethem
# Processing Record 9 of Set 15 | san ramon
# Processing Record 10 of Set 15 | champerico
# Processing Record 11 of Set 15 | port keats
# Processing Record 12 of Set 15 | wum
# Processing Record 13 of Set 15 | yakeshi
# Processing Record 14 of Set 15 | bandar-e lengeh
# Processing Record 15 of Set 15 | bamora
# Processing Record 16 of Set 15 | smithers
# Processing Record 17 of Set 15 | xingyi
# Processing Record 18 of Set 15 | shrewsbury
# Processing Record 19 of Set 15 | meulaboh
# Processing Record 20 of Set 15 | mayumba
# Processing Record 21 of Set 15 | terrace bay
# Processing Record 22 of Set 15 | natchitoches
# Processing Record 23 of Set 15 | homer
# Processing Record 24 of Set 15 | rocha
# Processing Record 25 of Set 15 | manadhoo
# Processing Record 26 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 15 | camacupa
# Processing Record 28 of Set 15 | evans
# Processing Record 29 of Set 15 | gwadar
# Processing Record 30 of Set 15 | tbilisskaya
# Processing Record 31 of Set 15 | valleyview
# Processing Record 32 of Set 15 | tairua
# Processing Record 33 of Set 15 | brae
# Processing Record 34 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 15 | sambava
# Processing Record 36 of Set 15 | tilichiki
# Processing Record 37 of Set 15 | magadan
# Processing Record 38 of Set 15 | saint-tite
# Processing Record 39 of Set 15 | bacungan
# Processing Record 40 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 15 | nelson bay
# Processing Record 42 of Set 15 | ilulissat
# Processing Record 43 of Set 15 | scarborough
# Processing Record 44 of Set 15 | gazojak
# Processing Record 45 of Set 15 | san quintin
# Processing Record 46 of Set 15 | nkayi
# Processing Record 47 of Set 15 | barsovo
# Processing Record 48 of Set 15 | terekli-mekteb
# Processing Record 49 of Set 15 | shirdi
# Processing Record 50 of Set 15 | kahului
# Processing Record 1 of Set 16 | havoysund
# Processing Record 2 of Set 16 | galbshtadt
# Processing Record 3 of Set 16 | altamont
# Processing Record 4 of Set 16 | matiguas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Tuktoyaktuk  69.45 -133.04     46.40        65          75       12.75
# 1    Busselton -33.65  115.33     45.00        92           0        1.83
# 2      Rikitea -23.12 -134.97     68.54        61           0        3.96
# 3      Colares  38.80   -9.45     71.01        94           3       18.77
# 4  Port Alfred -33.59   26.89     58.14        72           0       13.15
# 5     Cherskiy  68.75  161.30     41.86        92         100        1.25
# 6  Provideniya  64.38 -173.30     51.80        81          90        6.71
# 7        Paita  -5.09  -81.11     63.55        80           1       16.28
# 8       Dikson  73.51   80.55     47.62        83          38       10.25
# 9   Coahuayana  18.73 -103.68     71.60        83          90        6.42
#
#   Country Current Description
# 0      CA       broken clouds
# 1      AU           clear sky
# 2      PF           clear sky
# 3      PT           clear sky
# 4      ZA           clear sky
# 5      RU     overcast clouds
# 6      RU     overcast clouds
# 7      PE           clear sky
# 8      RU    scattered clouds
# 9      MX             drizzle

# %%
#new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tuktoyaktuk      CA  69.45 -133.04     46.40        65          75
# 1    Busselton      AU -33.65  115.33     45.00        92           0
# 2      Rikitea      PF -23.12 -134.97     68.54        61           0
# 3      Colares      PT  38.80   -9.45     71.01        94           3
# 4  Port Alfred      ZA -33.59   26.89     58.14        72           0
#
#    Wind Speed Current Description
# 0       12.75       broken clouds
# 1        1.83           clear sky
# 2        3.96           clear sky
# 3       18.77           clear sky
# 4       13.15           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
